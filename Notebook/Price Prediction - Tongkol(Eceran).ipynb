# %%
import csv
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

from dataclasses import dataclass
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv('/content/drive/MyDrive/ML/Data Price Prediction - All Data - Tongkol-Eceran.csv', sep =',')
Q1 = df1['Harga'].quantile(0.3)
Q3 = df1['Harga'].quantile(0.7)
IQR = Q3 - Q1
# df = df1[(df1['Harga'] >= Q1 - 1.5 * IQR) & (df1['Harga'] <= Q3 + 1.5 * IQR)]
threshold = 1.5*IQR
median = np.median(df1['Harga'])
outliers = (df1['Harga'] < Q1 - threshold) | (df1['Harga'] > Q3 + threshold)
df1[outliers] = median

# %%
def get_data(data):
    
    times = []
    value = []

    i = 0
    for row in data:
      times.append(i)
      value.append(float(row)/1000)
      i+=1
    
    return times, value

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Test your function and save all "global" variables within the G class (G stands for global)
@dataclass
class G:
    times, price = get_data(df1['Harga'])
    TIME = np.array(times)
    SERIES = np.array(price)
    SPLIT_TIME = 62
    WINDOW_SIZE = 12
    BATCH_SIZE = 12
    SHUFFLE_BUFFER_SIZE = 150

# %%
plt.figure()
plot_series(G.TIME, G.SERIES)
plt.show()

# %%
def train_val_split(time, series, time_step=G.SPLIT_TIME):

    time_train = time[:time_step]
    series_train = series[:time_step]
    time_valid = time[time_step:]
    series_valid = series[time_step:]

    return time_train, series_train, time_valid, series_valid

# %%
# Split the dataset
time_train, series_train, time_valid, series_valid = train_val_split(G.TIME, G.SERIES)

# %%
def windowed_dataset(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    ds = ds.batch(batch_size).prefetch(1)
    return ds

# %%
# Apply the transformation to the training set
train_set = windowed_dataset(series_train, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE)

# %% [markdown]
# # Build Model

# %%
def create_model():
    
    model = tf.keras.models.Sequential([ 
        tf.keras.layers.Conv1D(filters=32, kernel_size=3,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[G.WINDOW_SIZE, 1]),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
        tf.keras.layers.Dense(1),
        tf.keras.layers.Lambda(lambda x: x * 100)
    ]) 

    return model
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 12, 32)            128
#
#  bidirectional (Bidirectiona  (None, 12, 256)          164864
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 64)               73984
#  nal)
#
#  dense (Dense)               (None, 1)                 65
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 239,041
# Trainable params: 239,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Test your uncompiled model
uncompiled_model = create_model()

try:
    uncompiled_model.predict(train_set)
except:
    print("Your current architecture is incompatible with the windowed dataset, try adjusting it.")
else:
    print("Your current architecture is compatible with the windowed dataset! :)")
# Out:
# 5/5 [==============================] - 2s 97ms/step
# Your current architecture is compatible with the windowed dataset! :)

# %%
# Get initial weights
init_weights = model.get_weights()

# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD()

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 9s 39ms/step - loss: 2.8825 - lr: 1.0000e-08
# Epoch 2/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.8273 - lr: 1.1220e-08
# Epoch 3/100
# 5/5 [==============================] - 0s 39ms/step - loss: 2.7671 - lr: 1.2589e-08
# Epoch 4/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.7085 - lr: 1.4125e-08
# Epoch 5/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.6353 - lr: 1.5849e-08
# Epoch 6/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.5554 - lr: 1.7783e-08
# Epoch 7/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.4711 - lr: 1.9953e-08
# Epoch 8/100
# 5/5 [==============================] - 0s 36ms/step - loss: 2.3800 - lr: 2.2387e-08
# Epoch 9/100
# 5/5 [==============================] - 0s 36ms/step - loss: 2.3056 - lr: 2.5119e-08
# Epoch 10/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.2270 - lr: 2.8184e-08
# Epoch 11/100
# 5/5 [==============================] - 0s 37ms/step - loss: 2.1238 - lr: 3.1623e-08
# Epoch 12/100
# 5/5 [==============================] - 0s 36ms/step - loss: 2.0288 - lr: 3.5481e-08
# Epoch 13/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.9194 - lr: 3.9811e-08
# Epoch 14/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.8292 - lr: 4.4668e-08
# Epoch 15/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.7570 - lr: 5.0119e-08
# Epoch 16/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.6963 - lr: 5.6234e-08
# Epoch 17/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.6625 - lr: 6.3096e-08
# Epoch 18/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.6216 - lr: 7.0795e-08
# Epoch 19/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.5759 - lr: 7.9433e-08
# Epoch 20/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.5304 - lr: 8.9125e-08
# Epoch 21/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.5231 - lr: 1.0000e-07
# Epoch 22/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.5189 - lr: 1.1220e-07
# Epoch 23/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.5239 - lr: 1.2589e-07
# Epoch 24/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.5151 - lr: 1.4125e-07
# Epoch 25/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.5207 - lr: 1.5849e-07
# Epoch 26/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.5136 - lr: 1.7783e-07
# Epoch 27/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.5219 - lr: 1.9953e-07
# Epoch 28/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.5134 - lr: 2.2387e-07
# Epoch 29/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.5249 - lr: 2.5119e-07
# Epoch 30/100
# 5/5 [==============================] - 0s 64ms/step - loss: 1.5222 - lr: 2.8184e-07
# Epoch 31/100
# 5/5 [==============================] - 0s 62ms/step - loss: 1.5203 - lr: 3.1623e-07
# Epoch 32/100
# 5/5 [==============================] - 0s 67ms/step - loss: 1.5169 - lr: 3.5481e-07
# Epoch 33/100
# 5/5 [==============================] - 0s 60ms/step - loss: 1
# Epoch 76/100
# 5/5 [==============================] - 0s 35ms/step - loss: 12.7188 - lr: 5.6234e-05
# Epoch 77/100
# 5/5 [==============================] - 0s 66ms/step - loss: 13.4718 - lr: 6.3096e-05
# Epoch 78/100
# 5/5 [==============================] - 0s 61ms/step - loss: 13.3454 - lr: 7.0795e-05
# Epoch 79/100
# 5/5 [==============================] - 0s 62ms/step - loss: 14.0456 - lr: 7.9433e-05
# Epoch 80/100
# 5/5 [==============================] - 0s 66ms/step - loss: 14.9386 - lr: 8.9125e-05
# Epoch 81/100
# 5/5 [==============================] - 0s 60ms/step - loss: 16.0067 - lr: 1.0000e-04
# Epoch 82/100
# 5/5 [==============================] - 0s 61ms/step - loss: 16.1320 - lr: 1.1220e-04
# Epoch 83/100
# 5/5 [==============================] - 0s 59ms/step - loss: 16.9840 - lr: 1.2589e-04
# Epoch 84/100
# 5/5 [==============================] - 0s 47ms/step - loss: 17.9542 - lr: 1.4125e-04
# Epoch 85/100
# 5/5 [==============================] - 0s 35ms/step - loss: 19.9562 - lr: 1.5849e-04
# Epoch 86/100
# 5/5 [==============================] - 0s 40ms/step - loss: 20.1294 - lr: 1.7783e-04
# Epoch 87/100
# 5/5 [==============================] - 0s 34ms/step - loss: 21.3141 - lr: 1.9953e-04
# Epoch 88/100
# 5/5 [==============================] - 0s 36ms/step - loss: 21.7717 - lr: 2.2387e-04
# Epoch 89/100
# 5/5 [==============================] - 0s 34ms/step - loss: 23.2507 - lr: 2.5119e-04
# Epoch 90/100
# 5/5 [==============================] - 0s 34ms/step - loss: 24.3930 - lr: 2.8184e-04
# Epoch 91/100
# 5/5 [==============================] - 0s 36ms/step - loss: 26.2586 - lr: 3.1623e-04
# Epoch 92/100
# 5/5 [==============================] - 0s 35ms/step - loss: 27.2984 - lr: 3.5481e-04
# Epoch 93/100
# 5/5 [==============================] - 0s 37ms/step - loss: 29.0240 - lr: 3.9811e-04
# Epoch 94/100
# 5/5 [==============================] - 0s 40ms/step - loss: 29.4401 - lr: 4.4668e-04
# Epoch 95/100
# 5/5 [==============================] - 0s 35ms/step - loss: 30.8866 - lr: 5.0119e-04
# Epoch 96/100
# 5/5 [==============================] - 0s 36ms/step - loss: 30.7263 - lr: 5.6234e-04
# Epoch 97/100
# 5/5 [==============================] - 0s 37ms/step - loss: 32.1887 - lr: 6.3096e-04
# Epoch 98/100
# 5/5 [==============================] - 0s 37ms/step - loss: 30.4145 - lr: 7.0795e-04
# Epoch 99/100
# 5/5 [==============================] - 0s 36ms/step - loss: 30.5131 - lr: 7.9433e-04
# Epoch 100/100
# 5/5 [==============================] - 0s 34ms/step - loss: 29.2744 - lr: 8.9125e-04

# %%
# Define the learning rate array
lrs = 1e-8 * (10 ** (np.arange(100) / 20))

# Set the figure size
plt.figure(figsize=(10, 6))

# Set the grid
plt.grid(True)

# Plot the loss in log scale
plt.semilogx(lrs, history.history["loss"])

# Increase the tickmarks size
plt.tick_params('both', length=10, width=1, which='both')

# Set the plot boundaries
plt.axis([1e-8, 1e-3, 0, 50])
# Out:
# (1e-08, 0.001, 0.0, 50.0)

# %%
# Reset states generated by Keras
tf.keras.backend.clear_session()

# Reset the weights
model.set_weights(init_weights)

# %%
# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer = tf.keras.optimizers.SGD(learning_rate=1e-06,momentum=0.95),
              metrics=["mae"])

# %%
history = model.fit(train_set,epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 9s 47ms/step - loss: 2.4122 - mae: 2.8871
# Epoch 2/100
# 5/5 [==============================] - 0s 36ms/step - loss: 2.1923 - mae: 2.6595
# Epoch 3/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.6716 - mae: 3.1477
# Epoch 4/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.7750 - mae: 2.2307
# Epoch 5/100
# 5/5 [==============================] - 0s 34ms/step - loss: 2.0307 - mae: 2.4782
# Epoch 6/100
# 5/5 [==============================] - 0s 37ms/step - loss: 2.3355 - mae: 2.8245
# Epoch 7/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.8757 - mae: 2.3418
# Epoch 8/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.3520 - mae: 1.7650
# Epoch 9/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.5811 - mae: 2.0182
# Epoch 10/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.4624 - mae: 1.8994
# Epoch 11/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.2789 - mae: 1.6973
# Epoch 12/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.2379 - mae: 1.6522
# Epoch 13/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.1425 - mae: 1.5736
# Epoch 14/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.3647 - mae: 1.7874
# Epoch 15/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.2886 - mae: 1.7159
# Epoch 16/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.8443 - mae: 2.3127
# Epoch 17/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.7367 - mae: 3.2169
# Epoch 18/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.4467 - mae: 1.8985
# Epoch 19/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0725 - mae: 1.5048
# Epoch 20/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.2664 - mae: 1.7034
# Epoch 21/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.2242 - mae: 1.6697
# Epoch 22/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.4947 - mae: 1.9600
# Epoch 23/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.1971 - mae: 1.6253
# Epoch 24/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.3698 - mae: 1.8175
# Epoch 25/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.1275 - mae: 1.5680
# Epoch 26/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.0358 - mae: 1.4414
# Epoch 27/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.3685 - mae: 1.8174
# Epoch 28/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.3220 - mae: 1.7286
# Epoch 29/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.3292 - mae: 1.7563
# Epoch 30/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.9662 - mae: 2.4272
# Epoch 31/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.4765 - mae: 1.9015
# Epoch 32/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.8752 - mae: 2.3531
# Epoch 33/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.3416 - mae: 1.7542
# Epoch 34/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.4370 - mae: 1.8990
# Epoch 35/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.5291 - mae: 1.9795
# Epoch 36/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.7986 - mae: 2.2513
# Epoch 37/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.9648 - mae: 2.4252
# Epoch 38/100
# 5/5 [==============================] - 0s 60ms/step - loss: 1.2849 - mae: 1.7331
# Epoch 39/100
# 5/5 [==============================] - 0s 60ms/step - loss: 1.1331 - mae: 1.5589
# Epoch 40/100
# 5/5 [==============================] - 0s 64ms/step - loss: 1.5980 - mae: 2.0671
# Epoch 41/100
# 5/5 [==============================] - 0s 63ms/step - loss: 1.1229 - mae: 1.5407
# Epoch 42/100
# 5/5 [==============================] - 0s 61ms/step - loss: 1.1000 - mae: 1.5339
# Epoch 43/100
# 5/5 [==============================] - 0s 64ms/step - loss: 1.2319 - mae: 1.6797
# Epoch 44/100
# 5/5 [==============================] - 0s 60ms/step - loss: 1.1847 - mae: 1.5715
# Epoch 45/100
# 5/5 [==============================] - 0s 61ms/step - loss: 1.4159 - mae: 1.8676
# Epoch 46/100
# 5/5 [==============================] - 0s 68ms/step - loss: 1.6090 - mae: 2.0715
# Epoch 47/100
# 5/5 [==============================] - 0s 35ms/step - loss: 2.4008 - mae: 2.8772
# Epoch 48/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.2285 - mae: 1.6651
# Epoch 49/100
# 5/5 [==============================] - 0s 37ms/step - loss: 0.9994 - mae: 1.3965
# Epoch 50/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.1997 - mae: 1.6308
# Epoch 51/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.0919 - mae: 1.4979
# Epoch 52/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.0284 - mae: 1.4247
# Epoch 53/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.1469 - mae: 1.5824
# Epoch 54/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.2308 - mae: 1.6318
# Epoch 55/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.2101 - mae: 1.6647
# Epoch 56/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.2579 - mae: 1.6787
# Epoch 57/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.4055 - mae: 1.8487
# Epoch 58/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.1478 - mae: 1.5782
# Epoch 59/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.1435 - mae: 1.5352
# Epoch 60/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.2731 - mae: 1.7189
# Epoch 61/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.5279 - mae: 1.9925
# Epoch 62/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.0309 - mae: 1.4258
# Epoch 63/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.0198 - mae: 1.4194
# Epoch 64/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.1006 - mae: 1.5259
# Epoch 65/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.0484 - mae: 1.4577
# Epoch 66/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.3415 - mae: 1.7702
# Epoch 67/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.1990 - mae: 1.6337
# Epoch 68/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.9963 - mae: 1.3891
# Epoch 69/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.0060 - mae: 1.4020
# Epoch 70/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.1891 - mae: 1.6056
# Epoch 71/100
# 5/5 [==============================] - 0s 102ms/step - loss: 1.0811 - mae: 1.4994
# Epoch 72/100
# 5/5 [==============================] - 0s 80ms/step - loss: 1.2878 - mae: 1.7176
# Epoch 73/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.0989 - mae: 1.5259
# Epoch 74/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.1787 - mae: 1.6271
# Epoch 75/100
# 5/5 [==============================] - 1s 95ms/step - loss: 1.1819 - mae: 1.6216
# Epoch 76/100
# 5/5 [==============================] - 0s 52ms/step - loss: 1.3328 - mae: 1.7797
# Epoch 77/100
# 5/5 [==============================] - 0s 36ms/step - loss: 2.0875 - mae: 2.5527
# Epoch 78/100
# 5/5 [==============================] - 1s 106ms/step - loss: 2.1387 - mae: 2.6323
# Epoch 79/100
# 5/5 [==============================] - 1s 101ms/step - loss: 1.4915 - mae: 1.9404
# Epoch 80/100
# 5/5 [==============================] - 0s 62ms/step - loss: 1.0833 - mae: 1.5087
# Epoch 81/100
# 5/5 [==============================] - 0s 67ms/step - loss: 1.0202 - mae: 1.4223
# Epoch 82/100
# 5/5 [==============================] - 0s 66ms/step - loss: 1.0356 - mae: 1.4387
# Epoch 83/100
# 5/5 [==============================] - 0s 65ms/step - loss: 1.2469 - mae: 1.7092
# Epoch 84/100
# 5/5 [==============================] - 0s 64ms/step - loss: 1.2354 - mae: 1.6856
# Epoch 85/100
# 5/5 [==============================] - 0s 66ms/step - loss: 1.0670 - mae: 1.5038
# Epoch 86/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.0836 - mae: 1.5301
# Epoch 87/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2390 - mae: 1.6597
# Epoch 88/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.0106 - mae: 1.4165
# Epoch 89/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.0850 - mae: 1.5097
# Epoch 90/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.5387 - mae: 1.9550
# Epoch 91/100
# 5/5 [==============================] - 0s 34ms/step - loss: 1.1146 - mae: 1.5362
# Epoch 92/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.2917 - mae: 1.7412
# Epoch 93/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.0507 - mae: 1.4460
# Epoch 94/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1113 - mae: 1.5388
# Epoch 95/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.0366 - mae: 1.4493
# Epoch 96/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.1842 - mae: 1.5835
# Epoch 97/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.2757 - mae: 1.7301
# Epoch 98/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.0295 - mae: 1.4440
# Epoch 99/100
# 5/5 [==============================] - 0s 36ms/step - loss: 1.1903 - mae: 1.6301
# Epoch 100/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.4550 - mae: 1.9108

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    # Get predictions on the entire dataset
    forecast = model.predict(dataset)
    
    return forecast

# %%
def compute_metrics(true_series, forecast):
    
    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()

    return mse, mae

# %%
cnn_forecast = model_forecast(model, G.SERIES, G.WINDOW_SIZE, G.BATCH_SIZE).squeeze()
cnn_forecast = cnn_forecast[G.SPLIT_TIME - G.WINDOW_SIZE:-1]
mse, mae = compute_metrics(series_valid, cnn_forecast)

print(f"mse: {mse:.2f}, mae: {mae:.2f} for forecast")
# Out:
# 9/9 [==============================] - 2s 13ms/step
# mse: 5.81, mae: 2.02 for forecast

# %%
# Compute the forecast for all the series
cnn_forecast = model_forecast(model, G.SERIES, G.WINDOW_SIZE, G.BATCH_SIZE).squeeze()
tam = [None,None,None,None,None,None,None,None,None,None,None]


# Slice the forecast to get only the predictions for the validation set
# cnn_forecast = cnn_forecast[G.SPLIT_TIME - G.WINDOW_SIZE:-1]
cnn_forecast = np.insert(cnn_forecast, 0, tam)

# Plot the forecast
plt.figure(figsize=(10, 5))
plot_series(G.TIME, G.SERIES)
plot_series(G.TIME, cnn_forecast)
# Out:
# 9/9 [==============================] - 0s 13ms/step

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(100), history.history["loss"])
plt.plot(range(100), history.history["mae"])
plt.xlabel("Epochs")
plt.ylabel("Value")

plt.show()

# %%
# prepare data for forecasting
last_window = G.SERIES[-G.WINDOW_SIZE:]
last_window = np.reshape(last_window, (1, G.WINDOW_SIZE, 1))

# make a forecast for 5 steps ahead
forecast_norm = []
for _ in range(24):
    pred = model.predict(last_window)[0, 0]
    forecast_norm.append(pred)
    last_window = np.roll(last_window, -1, axis=1)
    last_window[0, -1, 0] = pred

# invert the normalization
forecast = forecast_norm
print("Forecast:", forecast)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# Forecast: [24.634209, 24.278893, 23.615797, 22.960394, 22.420563, 22.062918, 21.628727, 21.339743, 21.134094, 20.967276, 20.880144, 21.18815, 20.980865, 21.141838, 21.221657, 21.30052, 21.365469, 21.472763, 21.528135, 21.589329, 21.646519, 21.687689, 21.654137, 21.781664]

# %%
model.save("/content/drive/MyDrive/ML/Model/Price/Price Prediction - Tongkol(Eceran).h5")
