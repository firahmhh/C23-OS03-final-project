# %%
import csv
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

from dataclasses import dataclass
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/Bandeng-Grosir.csv', sep =',')

# %%
new_data = np.array_split(data, 8)

# %%
def remove_outlier(df1):
  Q1 = df1['Harga'].quantile(0.25)
  Q3 = df1['Harga'].quantile(0.75)
  IQR = Q3 - Q1
  # df = df1[(df1['Harga'] >= Q1 - 1.5 * IQR) & (df1['Harga'] <= Q3 + 1.5 * IQR)]
  threshold = 1.5*IQR
  median = np.median(df1['Harga'])
  outliers = (df1['Harga'] < Q1 - threshold) | (df1['Harga'] > Q3 + threshold)
  df1[outliers] = median
  return df1

# %%
df=pd.DataFrame()
for i in range(len(new_data)):
  new_data[i] = remove_outlier(new_data[i])

# %%
df = pd.concat(new_data)

# %%
def get_data(data):
    
    times = []
    value = []

    i = 0
    for row in data:
      times.append(i)
      value.append(float(row)/1000)
      i+=1

    
    return times, value

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Test your function and save all "global" variables within the G class (G stands for global)
@dataclass
class G:
    times, price = get_data(df['Harga'])
    TIME = np.array(times)
    SERIES = np.array(price)
    SPLIT_TIME = 72
    WINDOW_SIZE = 12
    BATCH_SIZE = 12
    SHUFFLE_BUFFER_SIZE = 150

# %%
plt.figure(figsize=(10, 8))
plot_series(G.TIME, G.SERIES)
plt.show()

# %%
def train_val_split(time, series, time_step=G.SPLIT_TIME):

    time_train = time[:time_step]
    series_train = series[:time_step]
    time_valid = time[time_step:]
    series_valid = series[time_step:]

    return time_train, series_train, time_valid, series_valid

# %%
# Split the dataset
time_train, series_train, time_valid, series_valid = train_val_split(G.TIME, G.SERIES)

# %%
def windowed_dataset(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    ds = ds.batch(batch_size).prefetch(1)
    return ds

# %%
# Apply the transformation to the training set
train_set = windowed_dataset(series_train, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE)

# %% [markdown]
# ## Build the Model

# %%
def create_model():
    
    model = tf.keras.models.Sequential([ 
        tf.keras.layers.Conv1D(filters=32, kernel_size=3,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[G.WINDOW_SIZE, 1]),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
        tf.keras.layers.Dense(1),
        tf.keras.layers.Lambda(lambda x: x * 100)
    ]) 

    return model
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 12, 32)            128
#
#  bidirectional (Bidirectiona  (None, 12, 256)          164864
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 64)               73984
#  nal)
#
#  dense (Dense)               (None, 1)                 65
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 239,041
# Trainable params: 239,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Test your uncompiled model
uncompiled_model = create_model()

try:
    uncompiled_model.predict(train_set)
except:
    print("Your current architecture is incompatible with the windowed dataset, try adjusting it.")
else:
    print("Your current architecture is compatible with the windowed dataset! :)")
# Out:
# 5/5 [==============================] - 3s 29ms/step
# Your current architecture is compatible with the windowed dataset! :)

# %%
# Get initial weights
init_weights = model.get_weights()

# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD(momentum=0.95)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 8s 44ms/step - loss: 38.9684 - lr: 1.0000e-08
# Epoch 2/100
# 5/5 [==============================] - 0s 38ms/step - loss: 38.6569 - lr: 1.1220e-08
# Epoch 3/100
# 5/5 [==============================] - 0s 44ms/step - loss: 38.0646 - lr: 1.2589e-08
# Epoch 4/100
# 5/5 [==============================] - 0s 42ms/step - loss: 37.2058 - lr: 1.4125e-08
# Epoch 5/100
# 5/5 [==============================] - 0s 52ms/step - loss: 36.0828 - lr: 1.5849e-08
# Epoch 6/100
# 5/5 [==============================] - 0s 46ms/step - loss: 34.6899 - lr: 1.7783e-08
# Epoch 7/100
# 5/5 [==============================] - 0s 40ms/step - loss: 33.0064 - lr: 1.9953e-08
# Epoch 8/100
# 5/5 [==============================] - 0s 38ms/step - loss: 31.0022 - lr: 2.2387e-08
# Epoch 9/100
# 5/5 [==============================] - 0s 43ms/step - loss: 28.6283 - lr: 2.5119e-08
# Epoch 10/100
# 5/5 [==============================] - 0s 41ms/step - loss: 25.8245 - lr: 2.8184e-08
# Epoch 11/100
# 5/5 [==============================] - 0s 43ms/step - loss: 22.4909 - lr: 3.1623e-08
# Epoch 12/100
# 5/5 [==============================] - 0s 38ms/step - loss: 18.5183 - lr: 3.5481e-08
# Epoch 13/100
# 5/5 [==============================] - 0s 39ms/step - loss: 13.7406 - lr: 3.9811e-08
# Epoch 14/100
# 5/5 [==============================] - 0s 42ms/step - loss: 7.9920 - lr: 4.4668e-08
# Epoch 15/100
# 5/5 [==============================] - 0s 43ms/step - loss: 2
# Set the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.95)

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %%
# Train the model
Epochs = 80
history = model.fit(train_set,epochs=Epochs)
# Out:
# Epoch 1/80
# 5/5 [==============================] - 10s 53ms/step - loss: 33.5067 - mae: 34.0067
# Epoch 2/80
# 5/5 [==============================] - 0s 46ms/step - loss: 10.9178 - mae: 11.4062
# Epoch 3/80
# 5/5 [==============================] - 0s 47ms/step - loss: 19.4796 - mae: 19.9796
# Epoch 4/80
# 5/5 [==============================] - 0s 43ms/step - loss: 6.8496 - mae: 7.3469
# Epoch 5/80
# 5/5 [==============================] - 0s 45ms/step - loss: 9.5662 - mae: 10.0662
# Epoch 6/80
# 5/5 [==============================] - 0s 45ms/step - loss: 5.3989 - mae: 5.8895
# Epoch 7/80
# 5/5 [==============================] - 0s 45ms/step - loss: 4.5514 - mae: 5.0514
# Epoch 8/80
# 5/5 [==============================] - 0s 45ms/step - loss: 6.3654 - mae: 6.8654
# Epoch 9/80
# 5/5 [==============================] - 0s 46ms/step - loss: 2.7168 - mae: 3.2131
# Epoch 10/80
# 5/5 [==============================] - 0s 47ms/step - loss: 3.6373 - mae: 4.1262
# Epoch 11/80
# 5/5 [==============================] - 0s 49ms/step - loss: 2.8792 - mae: 3.3522
# Epoch 12/80
# 5/5 [==============================] - 0s 43ms/step - loss: 1.3942 - mae: 1.8660
# Epoch 13/80
# 5/5 [==============================] - 0s 45ms/step - loss: 1.6344 - mae: 2.1021
# Epoch 14/80
# 5/5 [==============================] - 0s 45ms/step - loss: 1.0036 - mae: 1.4474
# Epoch 15/80
# 5/5 [==============================] - 0s 48ms/step - loss: 1.4264 - mae: 1.8706
# Epoch 16/80
# 5/5 [==============================] - 0s 78ms/step - loss: 1.2223 - mae: 1.6788
# Epoch 17/80
# 5/5 [==============================] - 0s 79ms/step - loss: 0.8002 - mae: 1.2007
# Epoch 18/80
# 5/5 [==============================] - 0s 77ms/step - loss: 0.7493 - mae: 1.1593
# Epoch 19/80
# 5/5 [==============================] - 0s 89ms/step - loss: 0.7095 - mae: 1.1165
# Epoch 20/80
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6938 - mae: 1.0972
# Epoch 21/80
# 5/5 [==============================] - 0s 78ms/step - loss: 0.7539 - mae: 1.1941
# Epoch 22/80
# 5/5 [==============================] - 0s 84ms/step - loss: 0.8600 - mae: 1.2808
# Epoch 23/80
# 5/5 [==============================] - 0s 79ms/step - loss: 0.6903 - mae: 1.1002
# Epoch 24/80
# 5/5 [==============================] - 0s 50ms/step - loss: 0.5695 - mae: 0.9650
# Epoch 25/80
# 5/5 [==============================] - 0s 49ms/step - loss: 0.6272 - mae: 1.0569
# Epoch 26/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.5801 - mae: 0.9592
# Epoch 27/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4850 - mae: 0.8872
# Epoch 28/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.5434 - mae: 0.9510
# Epoch 29/80
# 5/5 [==============================] - 0s 47ms/step - loss: 0.5097 - mae: 0.9038
# Epoch 30/80
# 5/5 [==============================] - 0s 48ms/step - loss: 0.4445 - mae: 0.8209
# Epoch 31/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.4380 - mae: 0.8147
# Epoch 32/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.4025 - mae: 0.7839
# Epoch 33/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.4688 - mae: 0.8538
# Epoch 34/80
# 5/5 [==============================] - 0s 49ms/step - loss: 0.4441 - mae: 0.8047
# Epoch 35/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.4474 - mae: 0.8315
# Epoch 36/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4008 - mae: 0.7640
# Epoch 37/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4044 - mae: 0.7880
# Epoch 38/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3927 - mae: 0.7649
# Epoch 39/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3960 - mae: 0.7755
# Epoch 40/80
# 5/5 [==============================] - 0s 49ms/step - loss: 0.3986 - mae: 0.7894
# Epoch 41/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3781 - mae: 0.7394
# Epoch 42/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3766 - mae: 0.7391
# Epoch 43/80
# 5/5 [==============================] - 0s 52ms/step - loss: 0.3677 - mae: 0.7311
# Epoch 44/80
# 5/5 [==============================] - 0s 47ms/step - loss: 0.3728 - mae: 0.7310
# Epoch 45/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3785 - mae: 0.7266
# Epoch 46/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3776 - mae: 0.7315
# Epoch 47/80
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4044 - mae: 0.7568
# Epoch 48/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3534 - mae: 0.7106
# Epoch 49/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.4148 - mae: 0.8072
# Epoch 50/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3555 - mae: 0.7015
# Epoch 51/80
# 5/5 [==============================] - 0s 51ms/step - loss: 0.3910 - mae: 0.7278
# Epoch 52/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3684 - mae: 0.7479
# Epoch 53/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3727 - mae: 0.7067
# Epoch 54/80
# 5/5 [==============================] - 0s 48ms/step - loss: 0.4192 - mae: 0.7835
# Epoch 55/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3850 - mae: 0.7341
# Epoch 56/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3734 - mae: 0.6994
# Epoch 57/80
# 5/5 [==============================] - 0s 47ms/step - loss: 0.3428 - mae: 0.6851
# Epoch 58/80
# 5/5 [==============================] - 0s 79ms/step - loss: 0.3216 - mae: 0.6593
# Epoch 59/80
# 5/5 [==============================] - 0s 80ms/step - loss: 0.3497 - mae: 0.6927
# Epoch 60/80
# 5/5 [==============================] - 0s 80ms/step - loss: 0.3823 - mae: 0.7297
# Epoch 61/80
# 5/5 [==============================] - 0s 80ms/step - loss: 0.3193 - mae: 0.6631
# Epoch 62/80
# 5/5 [==============================] - 0s 79ms/step - loss: 0.3331 - mae: 0.6630
# Epoch 63/80
# 5/5 [==============================] - 0s 88ms/step - loss: 0.3784 - mae: 0.7238
# Epoch 64/80
# 5/5 [==============================] - 0s 81ms/step - loss: 0.4370 - mae: 0.8020
# Epoch 65/80
# 5/5 [==============================] - 0s 43ms/step - loss: 0.3474 - mae: 0.6703
# Epoch 66/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3210 - mae: 0.6695
# Epoch 67/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3046 - mae: 0.6099
# Epoch 68/80
# 5/5 [==============================] - 0s 47ms/step - loss: 0.3304 - mae: 0.6648
# Epoch 69/80
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2931 - mae: 0.6069
# Epoch 70/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3371 - mae: 0.6756
# Epoch 71/80
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3266 - mae: 0.6503
# Epoch 72/80
# 5/5 [==============================] - 0s 45ms/step - loss: 0.3467 - mae: 0.6985
# Epoch 73/80
# 5/5 [==============================] - 0s 46ms/step - loss: 0.3963 - mae: 0.7464
# Epoch 74/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3955 - mae: 0.7869
# Epoch 75/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4240 - mae: 0.7966
# Epoch 76/80
# 5/5 [==============================] - 0s 42ms/step - loss: 0.3990 - mae: 0.7632
# Epoch 77/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.3957 - mae: 0.7736
# Epoch 78/80
# 5/5 [==============================] - 0s 48ms/step - loss: 0.3853 - mae: 0.7536
# Epoch 79/80
# 5/5 [==============================] - 0s 47ms/step - loss: 0.3642 - mae: 0.7219
# Epoch 80/80
# 5/5 [==============================] - 0s 44ms/step - loss: 0.4528 - mae: 0.8434

# %%
def model_forecast(model, series, window_size, batch_size):
    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    # Get predictions on the entire dataset
    forecast = model.predict(dataset)
    
    return forecast

# %%
def compute_metrics(true_series, forecast):
    
    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()

    return mse, mae

# %%
cnn_forecast = model_forecast(model, G.SERIES, G.WINDOW_SIZE, G.BATCH_SIZE).squeeze()
cnn_forecast = cnn_forecast[G.SPLIT_TIME - G.WINDOW_SIZE:-1]
mse, mae = compute_metrics(series_valid, cnn_forecast)

print(f"mse: {mse:.2f}, mae: {mae:.2f} for forecast")
# Out:
# 9/9 [==============================] - 2s 15ms/step
# mse: 5.93, mae: 1.65 for forecast

# %%
# Plot the forecast
plt.figure(figsize=(10, 5))
plot_series(time_valid, series_valid)
plot_series(time_valid, cnn_forecast)

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(10), history.history["loss"][:10])
plt.plot(range(10), history.history["mae"][:10])
plt.xlabel("Epochs")
plt.ylabel("Value")

plt.show()

# %%
# prepare data for forecasting
last_window = G.SERIES[-G.WINDOW_SIZE:]
last_window = np.reshape(last_window, (1, G.WINDOW_SIZE, 1))

# make a forecast for 5 steps ahead
forecast_norm = []
for _ in range(24):
    pred = model.predict(last_window)[0, 0]
    forecast_norm.append(pred)
    last_window = np.roll(last_window, -1, axis=1)
    last_window[0, -1, 0] = pred

# invert the normalization
forecast = forecast_norm
print("Forecast:", forecast)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# Forecast: [21.982725, 21.899351, 21.80782, 21.929842, 21.966349, 21.987734, 21.997063, 21.994944, 22.017172, 22.003279, 21.96512, 22.017708, 22.015034, 21.997244, 22.012257, 22.01976, 22.024353, 22.029846, 22.033762, 22.040886, 22.043606, 22.040936, 22.049662, 22.052803]

# %%
model.save('Bandengn(Grosir).h5')
