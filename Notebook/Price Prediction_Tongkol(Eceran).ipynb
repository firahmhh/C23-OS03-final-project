# %%
import csv
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

from dataclasses import dataclass
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_csv('/content/drive/MyDrive/ML/Data Price Prediction - All Data - Tongkol-Eceran.csv', sep =',')
Q1 = df1['Harga'].quantile(0.3)
Q3 = df1['Harga'].quantile(0.7)
IQR = Q3 - Q1
# df = df1[(df1['Harga'] >= Q1 - 1.5 * IQR) & (df1['Harga'] <= Q3 + 1.5 * IQR)]
threshold = 1.5*IQR
median = np.median(df1['Harga'])
outliers = (df1['Harga'] < Q1 - threshold) | (df1['Harga'] > Q3 + threshold)
df1[outliers] = median

# %%
def get_data(data):
    
    times = []
    value = []

    i = 0
    for row in data:
      times.append(i)
      value.append(float(row)/1000)
      i+=1
    
    return times, value

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
# Test your function and save all "global" variables within the G class (G stands for global)
@dataclass
class G:
    times, price = get_data(df1['Harga'])
    TIME = np.array(times)
    SERIES = np.array(price)
    SPLIT_TIME = 62
    WINDOW_SIZE = 12
    BATCH_SIZE = 12
    SHUFFLE_BUFFER_SIZE = 150

# %%
plt.figure()
plot_series(G.TIME, G.SERIES)
plt.show()

# %%
def train_val_split(time, series, time_step=G.SPLIT_TIME):

    time_train = time[:time_step]
    series_train = series[:time_step]
    time_valid = time[time_step:]
    series_valid = series[time_step:]

    return time_train, series_train, time_valid, series_valid

# %%
# Split the dataset
time_train, series_train, time_valid, series_valid = train_val_split(G.TIME, G.SERIES)

# %%
def windowed_dataset(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    ds = ds.batch(batch_size).prefetch(1)
    return ds

# %%
# Apply the transformation to the training set
train_set = windowed_dataset(series_train, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE)

# %% [markdown]
# # Build Model

# %%
def create_model():
    
    model = tf.keras.models.Sequential([ 
        tf.keras.layers.Conv1D(filters=32, kernel_size=3,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[G.WINDOW_SIZE, 1]),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
        tf.keras.layers.Dense(1),
        tf.keras.layers.Lambda(lambda x: x * 100)
    ]) 

    return model
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 12, 32)            128
#
#  bidirectional (Bidirectiona  (None, 12, 256)          164864
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 64)               73984
#  nal)
#
#  dense (Dense)               (None, 1)                 65
#
#  lambda (Lambda)             (None, 1)                 0
#
# =================================================================
# Total params: 239,041
# Trainable params: 239,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Test your uncompiled model
uncompiled_model = create_model()

try:
    uncompiled_model.predict(train_set)
except:
    print("Your current architecture is incompatible with the windowed dataset, try adjusting it.")
else:
    print("Your current architecture is compatible with the windowed dataset! :)")
# Out:
# 5/5 [==============================] - 5s 26ms/step
# Your current architecture is compatible with the windowed dataset! :)

# %%
# Get initial weights
init_weights = model.get_weights()

# Set the learning rate scheduler
lr_schedule = tf.keras.callbacks.LearningRateScheduler(
    lambda epoch: 1e-8 * 10**(epoch / 20))

# Initialize the optimizer
optimizer = tf.keras.optimizers.SGD()

# Set the training parameters
model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer)

# Train the model
history = model.fit(train_set, epochs=100, callbacks=[lr_schedule])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 8s 44ms/step - loss: 64.7824 - lr: 1.0000e-08
# Epoch 2/100
# 5/5 [==============================] - 0s 44ms/step - loss: 64.7276 - lr: 1.1220e-08
# Epoch 3/100
# 5/5 [==============================] - 0s 42ms/step - loss: 64.6659 - lr: 1.2589e-08
# Epoch 4/100
# 5/5 [==============================] - 0s 41ms/step - loss: 64.5967 - lr: 1.4125e-08
# Epoch 5/100
# 5/5 [==============================] - 0s 43ms/step - loss: 64.5194 - lr: 1.5849e-08
# Epoch 6/100
# 5/5 [==============================] - 0s 42ms/step - loss: 64.4321 - lr: 1.7783e-08
# Epoch 7/100
# 5/5 [==============================] - 0s 47ms/step - loss: 64.3348 - lr: 1.9953e-08
# Epoch 8/100
# 5/5 [==============================] - 0s 39ms/step - loss: 64.2258 - lr: 2.2387e-08
# Epoch 9/100
# 5/5 [==============================] - 0s 40ms/step - loss: 64.1030 - lr: 2.5119e-08
# Epoch 10/100
# 5/5 [==============================] - 0s 40ms/step - loss: 63.9663 - lr: 2.8184e-08
# Epoch 11/100
# 5/5 [==============================] - 0s 42ms/step - loss: 63.8122 - lr: 3.1623e-08
# Epoch 12/100
# 5/5 [==============================] - 0s 42ms/step - loss: 63.6396 - lr: 3.5481e-08
# Epoch 13/100
# 5/5 [==============================] - 0s 51ms/step - loss: 63.4465 - lr: 3.9811e-08
# Epoch 14/100
# 5/5 [==============================] - 0s 77ms/step - loss: 63.2295 - lr: 4.4668e-08
# Epoch 15/100
# 5/5 [==============================] - 0s 74ms/step - loss: 62.9856 - lr: 5.0119e-08
# Epoch 16/100
# 5/5 [==============================] - 0s 71ms/step - loss: 62.7116 - lr: 5.6234e-08
# Epoch 17/100
100
# 5/5 [==============================] - 0s 38ms/step - loss: 2.8004 - mae: 3.2701
# Epoch 16/100
# 5/5 [==============================] - 0s 40ms/step - loss: 2.2338 - mae: 2.6982
# Epoch 17/100
# 5/5 [==============================] - 0s 76ms/step - loss: 1.8384 - mae: 2.2967
# Epoch 18/100
# 5/5 [==============================] - 0s 71ms/step - loss: 2.2316 - mae: 2.6854
# Epoch 19/100
# 5/5 [==============================] - 0s 82ms/step - loss: 2.1313 - mae: 2.5898
# Epoch 20/100
# 5/5 [==============================] - 0s 78ms/step - loss: 1.8627 - mae: 2.2950
# Epoch 21/100
# 5/5 [==============================] - 0s 70ms/step - loss: 1.9940 - mae: 2.4576
# Epoch 22/100
# 5/5 [==============================] - 0s 70ms/step - loss: 1.4830 - mae: 1.9260
# Epoch 23/100
# 5/5 [==============================] - 0s 69ms/step - loss: 1.6543 - mae: 2.0802
# Epoch 24/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.4979 - mae: 1.9463
# Epoch 25/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.4990 - mae: 1.9150
# Epoch 26/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.5785 - mae: 2.0241
# Epoch 27/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.5547 - mae: 2.0008
# Epoch 28/100
# 5/5 [==============================] - 0s 48ms/step - loss: 1.5281 - mae: 1.9791
# Epoch 29/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.4464 - mae: 1.8867
# Epoch 30/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.6396 - mae: 2.0983
# Epoch 31/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.4289 - mae: 1.8632
# Epoch 32/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.4342 - mae: 1.8666
# Epoch 33/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.6356 - mae: 2.0805
# Epoch 34/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.4086 - mae: 1.8324
# Epoch 35/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.5750 - mae: 2.0086
# Epoch 36/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.5016 - mae: 1.9537
# Epoch 37/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.3889 - mae: 1.8254
# Epoch 38/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.4813 - mae: 1.9064
# Epoch 39/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.3302 - mae: 1.7665
# Epoch 40/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.3210 - mae: 1.7585
# Epoch 41/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.3421 - mae: 1.7576
# Epoch 42/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.3138 - mae: 1.7360
# Epoch 43/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.2959 - mae: 1.7255
# Epoch 44/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.4239 - mae: 1.8561
# Epoch 45/100
# 5/5 [==============================] - 0s 37ms/step - loss: 1.2753 - mae: 1.6861
# Epoch 46/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.3482 - mae: 1.7798
# Epoch 47/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.3254 - mae: 1.7666
# Epoch 48/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.2967 - mae: 1.7339
# Epoch 49/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.2556 - mae: 1.6752
# Epoch 50/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2575 - mae: 1.6764
# Epoch 51/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.3324 - mae: 1.7796
# Epoch 52/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2304 - mae: 1.6452
# Epoch 53/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.3189 - mae: 1.7451
# Epoch 54/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.2196 - mae: 1.6535
# Epoch 55/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.1825 - mae: 1.6045
# Epoch 56/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.6687 - mae: 2.1257
# Epoch 57/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.4428 - mae: 1.9014
# Epoch 58/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.5555 - mae: 2.0058
# Epoch 59/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.5990 - mae: 2.0273
# Epoch 60/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.2812 - mae: 1.7111
# Epoch 61/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2008 - mae: 1.6126
# Epoch 62/100
# 5/5 [==============================] - 0s 62ms/step - loss: 1.5043 - mae: 1.9563
# Epoch 63/100
# 5/5 [==============================] - 0s 72ms/step - loss: 1.3309 - mae: 1.7779
# Epoch 64/100
# 5/5 [==============================] - 0s 72ms/step - loss: 1.1805 - mae: 1.5989
# Epoch 65/100
# 5/5 [==============================] - 0s 67ms/step - loss: 1.5119 - mae: 1.9582
# Epoch 66/100
# 5/5 [==============================] - 0s 68ms/step - loss: 1.2137 - mae: 1.6511
# Epoch 67/100
# 5/5 [==============================] - 0s 69ms/step - loss: 1.2482 - mae: 1.6945
# Epoch 68/100
# 5/5 [==============================] - 0s 67ms/step - loss: 1.2679 - mae: 1.7079
# Epoch 69/100
# 5/5 [==============================] - 0s 60ms/step - loss: 1.1324 - mae: 1.5433
# Epoch 70/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.1058 - mae: 1.5209
# Epoch 71/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1020 - mae: 1.5039
# Epoch 72/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0986 - mae: 1.5246
# Epoch 73/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1735 - mae: 1.5704
# Epoch 74/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1238 - mae: 1.5409
# Epoch 75/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1921 - mae: 1.6142
# Epoch 76/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1074 - mae: 1.5209
# Epoch 77/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.0930 - mae: 1.5101
# Epoch 78/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0817 - mae: 1.4954
# Epoch 79/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1014 - mae: 1.5174
# Epoch 80/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.2099 - mae: 1.6254
# Epoch 81/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2941 - mae: 1.7243
# Epoch 82/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2304 - mae: 1.6722
# Epoch 83/100
# 5/5 [==============================] - 0s 47ms/step - loss: 1.1253 - mae: 1.5381
# Epoch 84/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.2230 - mae: 1.6649
# Epoch 85/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.3091 - mae: 1.7214
# Epoch 86/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.0630 - mae: 1.4815
# Epoch 87/100
# 5/5 [==============================] - 0s 41ms/step - loss: 1.3401 - mae: 1.7892
# Epoch 88/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.0952 - mae: 1.5147
# Epoch 89/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0596 - mae: 1.4832
# Epoch 90/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.0744 - mae: 1.4798
# Epoch 91/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.0923 - mae: 1.5042
# Epoch 92/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0283 - mae: 1.4285
# Epoch 93/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.0584 - mae: 1.4797
# Epoch 94/100
# 5/5 [==============================] - 0s 43ms/step - loss: 1.0320 - mae: 1.4265
# Epoch 95/100
# 5/5 [==============================] - 0s 38ms/step - loss: 1.0272 - mae: 1.4183
# Epoch 96/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0410 - mae: 1.4517
# Epoch 97/100
# 5/5 [==============================] - 0s 40ms/step - loss: 1.1138 - mae: 1.5173
# Epoch 98/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1553 - mae: 1.5594
# Epoch 99/100
# 5/5 [==============================] - 0s 42ms/step - loss: 1.1209 - mae: 1.5522
# Epoch 100/100
# 5/5 [==============================] - 0s 39ms/step - loss: 1.0667 - mae: 1.4439

# %%
def model_forecast(model, series, window_size, batch_size):
    """Uses an input model to generate predictions on data windows

    Args:
      model (TF Keras Model) - model that accepts data windows
      series (array of float) - contains the values of the time series
      window_size (int) - the number of time steps to include in the window
      batch_size (int) - the batch size

    Returns:
      forecast (numpy array) - array containing predictions
    """

    # Generate a TF Dataset from the series values
    dataset = tf.data.Dataset.from_tensor_slices(series)

    # Window the data but only take those with the specified size
    dataset = dataset.window(window_size, shift=1, drop_remainder=True)

    # Flatten the windows by putting its elements in a single batch
    dataset = dataset.flat_map(lambda w: w.batch(window_size))
    
    # Create batches of windows
    dataset = dataset.batch(batch_size).prefetch(1)
    
    # Get predictions on the entire dataset
    forecast = model.predict(dataset)
    
    return forecast

# %%
def compute_metrics(true_series, forecast):
    
    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()

    return mse, mae

# %%
cnn_forecast = model_forecast(model, G.SERIES, G.WINDOW_SIZE, G.BATCH_SIZE).squeeze()
cnn_forecast = cnn_forecast[G.SPLIT_TIME - G.WINDOW_SIZE:-1]
mse, mae = compute_metrics(series_valid, cnn_forecast)

print(f"mse: {mse:.2f}, mae: {mae:.2f} for forecast")
# Out:
# 8/8 [==============================] - 2s 26ms/step
# mse: 5.70, mae: 2.02 for forecast

# %%
# Compute the forecast for all the series
cnn_forecast = model_forecast(model, G.SERIES, G.WINDOW_SIZE, G.BATCH_SIZE).squeeze()
tam = [None,None,None,None,None,None,None,None,None,None,None]


# Slice the forecast to get only the predictions for the validation set
# cnn_forecast = cnn_forecast[G.SPLIT_TIME - G.WINDOW_SIZE:-1]
cnn_forecast = np.insert(cnn_forecast, 0, tam)

# Plot the forecast
plt.figure(figsize=(10, 5))
plot_series(G.TIME, G.SERIES)
plot_series(G.TIME, cnn_forecast)
# Out:
# 8/8 [==============================] - 0s 25ms/step

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(100), history.history["loss"])
plt.plot(range(100), history.history["mae"])
plt.xlabel("Epochs")
plt.ylabel("Value")

plt.show()

# %%
# prepare data for forecasting
last_window = G.SERIES[-G.WINDOW_SIZE:]
last_window = np.reshape(last_window, (1, G.WINDOW_SIZE, 1))

# make a forecast for 5 steps ahead
forecast_norm = []
for _ in range(24):
    pred = model.predict(last_window)[0, 0]
    forecast_norm.append(pred)
    last_window = np.roll(last_window, -1, axis=1)
    last_window[0, -1, 0] = pred

# invert the normalization
forecast = forecast_norm
print("Forecast:", forecast)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# Forecast: [23.642311, 23.245504, 24.08456, 24.683601, 24.822409, 25.234423, 25.730675, 25.884401, 26.067225, 26.588148, 27.025301, 26.829985, 26.876837, 26.844168, 26.664362, 26.544273, 26.396692, 26.221048, 26.07013, 25.932804, 25.77858, 25.63131, 25.542498, 25.477938]

# %%
model.save("/content/drive/MyDrive/ML/Model/Price/Price Prediction - Tongkol(Eceran).h5")
